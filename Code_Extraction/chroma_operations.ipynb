# %% [markdown]
# ## Chroma Database Initialization
# ### (Please run this first time if you pulled from Github)

# %% [markdown]
# ### 1. Set client

# %%
from chromadb.config import Settings
from chromadb import Client, PersistentClient

# %%
client = Client(Settings())
client = PersistentClient(path="./chroma_db")

# %% [markdown]
# ### 2. Create collection (if haven't already)

# %% [markdown]
# #### *CAUTION: Choose one only

# %% [markdown]
# MULTIPLE Collections

# %%
# Multiple Collections
client.create_collection(name="polyu_eee_document")
# Out:
# Collection(name=polyu_eee_document)

# %%
client.create_collection(name="polyu_sao_webpage")
# Out:
# Collection(name=polyu_sao_webpage)

# %%
client.create_collection(name="polyu_cus_webpage")
# Out:
# Collection(name=polyu_cus_webpage)

# %% [markdown]
# SINGLE Collection

# %%
# Single Collection
client.create_collection(name="vaa_documents")

# %% [markdown]
# ### 3. Delete collection (if needed)

# %% [markdown]
# #### *CAUTION: Choose one only

# %% [markdown]
# MULTIPLE Collections

# %%
# Multiple Collections
client.delete_collection(name="polyu_eee_document")

# %%
client.delete_collection(name="polyu_sao_webpage")

# %%
client.delete_collection(name="polyu_cus_webpage")

# %% [markdown]
# SINGLE Collection

# %%
# Single Collection
client.delete_collection(name="vaa_documents")

# %% [markdown]
# ### 4. Other operations

# %% [markdown]
# Check all collections

# %%
client.list_collections()
# Out:
# [Collection(name=polyu_cus_webpage),
#  Collection(name=polyu_sao_webpage),
#  Collection(name=polyu_eee_document)]
