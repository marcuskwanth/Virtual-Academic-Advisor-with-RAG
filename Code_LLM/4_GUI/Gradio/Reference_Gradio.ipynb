# %%
from langchain_ollama import ChatOllama
from langchain.schema import AIMessage, HumanMessage, SystemMessage
import gradio as gr

# %%
system_message = "You are a helpful assistant."

# %%
llm = ChatOllama(model="deepseek-r1:8b", validate_model_on_init=True, temperature=0.6, reasoning=True)


def stream_response(message, history):
    print(f"Input: {message}. History: {history}\n")

    history_langchain_format = []
    history_langchain_format.append(SystemMessage(content=system_message))

    for human, ai in history:
        history_langchain_format.append(HumanMessage(content=human))
        history_langchain_format.append(AIMessage(content=ai))

    if message is not None:
        history_langchain_format.append(HumanMessage(content=message))
        partial_message = ""
        for response in llm.stream(history_langchain_format):
            partial_message += response.content
            yield partial_message


demo_interface = gr.ChatInterface(

    stream_response,
    textbox=gr.Textbox(placeholder="Send to the LLM...",
                       container=False,
                       autoscroll=True,
                       scale=7),
)

demo_interface.launch(share=True, debug=True)
# Out:
# /opt/anaconda3/envs/FYPEnv/lib/python3.12/site-packages/gradio/chat_interface.py:347: UserWarning: The 'tuples' format for chatbot messages is deprecated and will be removed in a future version of Gradio. Please set type='messages' instead, which uses openai-style 'role' and 'content' keys.
#   self.chatbot = Chatbot(
# * Running on local URL:  http://127.0.0.1:7860
# * Running on public URL: https://3aa08c4e56734008ff.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://3aa08c4e56734008ff.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# Input: Hello. History: []
#
# Input: Write a 1000 words paragraph about LLm. History: [['Hello', 'Hello! How can I help you today?']]
#
# Input: What had we discussed just now?. History: [['Hello', 'Hello! How can I help you today?'], ['Write a 1000 words paragraph about LLm', 'Okay, here is a 1000-word paragraph about Large Language Models (LLMs), covering their definition, underlying technology, capabilities, applications, and some associated considerations.\n\n---\n\n# Unpacking the Powerhouse: An Overview of Large Language Models (LLMs)\n\nIn the remarkably rapid evolution of artificial intelligence, few developments have captured the imagination and reshaped the technological landscape quite like Large Language Models (LLMs). These sophisticated AI systems represent a monumental leap in our ability to process, understand, and generate human-like text. At their core, LLMs are deep learning models, typically based on the Transformer architecture, trained on vast, diverse datasets comprising text and code from the internet and other sources. Their "large" nature stems not just from their ability to process language but from their immense scale – requiring billions of parameters (the numerical weights learned during training) and often involving training datasets containing petabytes of text. This scale allows them to learn intricate patterns, nuances, and statistical regularities inherent in human language, enabling capabilities far beyond simple text prediction.\n\nThe foundation of an LLM\'s power lies in its training process. These models are trained in an unsupervised manner, meaning they learn by predicting the next word (or token, a sub-unit of text) in a sequence, given the context provided by the preceding words. This seemingly simple task, when applied at scale across diverse data, allows the model to absorb grammar, facts, logic, style, and even implicit cultural knowledge present in the vast corpus it was trained on. This unsupervised pre-training phase builds a broad, foundational understanding of language. Subsequent stages, often involving fine-tuning on specific tasks or datasets, allow the model to adapt its capabilities for particular purposes, such as sentiment analysis, summarization, question answering, or code generation. The Transformer architecture, with its self-attention mechanism, is key to this efficiency. Self-attention allows the model to dynamically weigh the importance of different words in a sentence when predicting the next one, enabling a deep understanding of context, long-range dependencies, and semantic relationships that previous architectures struggled with.\n\nThe capabilities unlocked by LLMs are diverse and transformative. They excel at tasks involving language understanding and generation, including translating languages with improved fluency, summarizing long documents into concise and coherent overviews, answering complex questions based on provided context or internal knowledge (though often limited by the training data cutoff), generating creative text like poetry, stories, and scripts, drafting emails, code, and even technical documentation, and engaging in conversational dialogue. They can mimic different writing styles, provide explanations for complex topics, and synthesize information in novel ways. This versatility has led to their rapid integration across countless domains and applications.\n\nThe applications of LLMs are vast and expanding daily. In the enterprise sector, they power sophisticated customer service chatbots that can handle complex queries, automate content generation for marketing and journalism, assist developers with code generation and debugging tools, and enable data analysis through natural language queries. For developers and researchers, LLMs serve as powerful tools for generating boilerplate code, explaining algorithms, summarizing research papers, and even brainstorming creative concepts. They are democratizing access to powerful language processing capabilities, lowering the barrier for building sophisticated text-based applications. Content creators leverage them for drafting, edi ...
#
# Keyboard interruption in main thread... closing server.
# Killing tunnel 127.0.0.1:7860 <> https://3aa08c4e56734008ff.gradio.live
